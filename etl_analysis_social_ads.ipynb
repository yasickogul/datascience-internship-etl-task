# %% [markdown]
# <a href="https://colab.research.google.com/github/yasickogul/datascience-internship-etl-task/blob/main/etl_analysis_social_ads.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = "https://raw.githubusercontent.com/yasickogul/datascience-internship-etl-task/main/social_ads.csv"

# %%
#Extract
df = pd.read_csv(url)
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
print("Rows and Columns:", df.shape)
# Out:
# Rows and Columns: (400, 3)

# %% [markdown]
# TASK 1
#
# Columns
#
# Age: Age of the individual (numeric)
#
# EstimatedSalary: Annual income (numeric)
#
# Purchased: Whether the person purchased the product (1 = Yes, 0 = No)
#
# Number of columns = 3
# Number of rows = 400

# %%
#TASK 2
#Transform
# Check for nulls
print(df.isnull().sum())

# Check duplicates
df.drop_duplicates(inplace=True)

#Load
df.to_csv('cleaned_social_network_ads.csv', index=False)
# Out:
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
# Print shape
print("Dataset Shape:", df.shape)

# Print descriptive stats rounded to 2 decimals
print("\nDescriptive Statistics:")
print(df.describe().round(2))

# Purchase distribution
print("\nPurchase Distribution:")
print(df['Purchased'].value_counts())
# Out:
# Dataset Shape: (367, 3)
#
# Descriptive Statistics:
#           Age  EstimatedSalary  Purchased
# count  367.00           367.00     367.00
# mean    37.72         70719.35       0.38
# std     10.68         34772.17       0.49
# min     18.00         15000.00       0.00
# 25%     29.50         43000.00       0.00
# 50%     37.00         71000.00       0.00
# 75%     46.00         89000.00       1.00
# max     60.00        150000.00       1.00
#
# Purchase Distribution:
# Purchased
# 0    229
# 1    138
# Name: count, dtype: int64

# %%
#Purchase Distribution
sns.countplot(data=df, x="Purchased")
plt.title("Purchase Distribution")
plt.xlabel("Purchased (0 = No, 1 = Yes)")
plt.ylabel("Number of Users")
plt.show()

# %%
# Age vs Purchase
sns.boxplot(data=df, x="Purchased", y="Age")
plt.title("Age Distribution by Purchase Status")
plt.show()

# %%
#Estimated Salary vs Purchase
sns.boxplot(data=df, x="Purchased", y="EstimatedSalary")
plt.title("Salary Distribution by Purchase Status")
plt.show()

# %%
#Age vs Estimated Salary (Colored by Purchase)
sns.scatterplot(data=df, x="Age", y="EstimatedSalary", hue="Purchased")
plt.title("Age vs Salary (Purchase Highlighted)")
plt.show()

# %%
#Correlation Matrix
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()
